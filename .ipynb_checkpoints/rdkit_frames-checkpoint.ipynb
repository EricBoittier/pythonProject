# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np
from pathlib import Path
import networkx as nx
import matplotlib.pyplot as plt
from rdkit.Chem import Draw
from IPython.display import Image, HTML, display



def mol_to_nx(mol):
    G = nx.Graph()

    for atom in mol.GetAtoms():
        G.add_node(atom.GetIdx(),
                   atomic_num=atom.GetAtomicNum(),
                   is_aromatic=atom.GetIsAromatic(),
                   atom_symbol=atom.GetSymbol())
        
    for bond in mol.GetBonds():
        G.add_edge(bond.GetBeginAtomIdx(),
                   bond.GetEndAtomIdx(),
                   bond_type=bond.GetBondType())
        
    return G

def draw_mol_nx(Gmol):
    Gmol_atom = nx.get_node_attributes(Gmol, 'atom_symbol')
    Gmol_atom = {k: f"{k}.{v}" for k,v in list(Gmol_atom.items())}
    color_map = {'C': 'orange',
                 'O': 'red',
                 'N': 'blue',
                 'S': 'yellow',
                'H': "grey"}  

    _colors = []
    for idx in Gmol.nodes():
        if (Gmol.nodes[idx]['atom_symbol'] in color_map):
            _colors.append(color_map[Gmol.nodes[idx]['atom_symbol']])

    return nx.draw(Gmol,
            pos=nx.kamada_kawai_layout(Gmol),
            labels=Gmol_atom,
            with_labels = True,
            node_color=_colors,
            node_size=800)

# %%
# pdb_files = list(pdb_path.glob("*-min.pdb.sdf"))
# mols = np.array([load_pdb_mol(x) for x in pdb_files])

# def load_pdb_mol(filename):
#     pdb = open(filename).read()
#     mol = Chem.MolFromPDBBlock(pdb, sanitize=True, removeHs=False)
#     return mol



sdf_files = list(pdb_path.glob("*-min.pdb.sdf"))

mols = []
for sdf_file in sdf_files:
    m = next(Chem.SDMolSupplier(str(sdf_file)))
    print(sdf_file, m)
    mols.append(m)

names = [str(n.stem).split("-")[0].upper() for n in pdb_files]
formal_charges = [rdkit.Chem.rdmolops.GetFormalCharge(m) for m in mols]
legends = [f"{n} ({fc})" for fc, n in zip(formal_charges, names)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pdb_path = Path(__file__).parent.parent / "pdb"
#       2 # pdb_files = list(pdb_path.glob("*-min.pdb.sdf"))
#       3 # mols = np.array([load_pdb_mol(x) for x in pdb_files])
#       4
#    (...)
#       7 #     mol = Chem.MolFromPDBBlock(pdb, sanitize=True, removeHs=False)
#       8 #     return mol
#      12 sdf_files = list(pdb_path.glob("*-min.pdb.sdf"))
#
# NameError: name '__file__' is not defined

# %%
rdkit.Chem.Draw.MolsToGridImage(mols, legends=legends)

# %%
Gmols = [mol_to_nx(mol) for mol in mols]

# %%
Gmols
# Out:
# [<networkx.classes.graph.Graph at 0x7f48cbf58190>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3250>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3700>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3820>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3370>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3730>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3970>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3310>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3eb0>,
#  <networkx.classes.graph.Graph at 0x7f48cbef39a0>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3550>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3f70>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3fa0>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3580>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3bb0>,
#  <networkx.classes.graph.Graph at 0x7f48d00436d0>,
#  <networkx.classes.graph.Graph at 0x7f48cbef3e50>,
#  <networkx.classes.graph.Graph at 0x7f48cbee8310>,
#  <networkx.classes.graph.Graph at 0x7f48cbee8640>,
#  <networkx.classes.graph.Graph at 0x7f48cbee8100>,
#  <networkx.classes.graph.Graph at 0x7f48cbee8d00>,
#  <networkx.classes.graph.Graph at 0x7f48cbee8040>,
#  <networkx.classes.graph.Graph at 0x7f48cbee88e0>]

# %%
for i in range(len(Gmols)):
    ans = [_[1] for _ in list(Gmols[i].nodes.data("atomic_num"))]
    noS = not(16 in ans )
    if formal_charges[i] == 0 and noS:
        draw_mol_nx(Gmols[i])
        plt.title(f"{names[i]}")
        plt.show()

# %%
molecule = mols[0]
AllChem.Compute2DCoords(molecule)
Chem.SanitizeMol(molecule)
molecule = Chem.RemoveHs(molecule)
fp = AllChem.GetMorganFingerprintAsBitVect(molecule, radius=1)

def map_fp_bits_to_atoms(mol, fp):
    bit_info = {}
    AllChem.GetMorganFingerprint(mol, radius=1, bitInfo=bit_info)
    return {bit: list(atoms) for bit, atoms in bit_info.items()}
atom_maps = map_fp_bits_to_atoms(molecule, fp)

# %%
mols[0]

# %%
bi = {}
fp = AllChem.GetMorganFingerprintAsBitVect(molecule, radius=0, bitInfo=bi)

bits = list(bi.keys())
print(bits)

pngs = []


for bit in bits:
    hits = bi[bit]
    print(bit, hits)
    hit_atoms = set()
    hit_bonds = set()
    for atom_idx, radius in hits:
        if radius == 0:
            hit_atoms.add(atom_idx)
        elif radius == 1:
            bond = molecule.GetBondBetweenAtoms(atom_idx, hits[0][0])
            if bond:
                hit_bonds.add(bond.GetIdx())

    # Draw the molecule with highlighted atoms and bonds
    d = Draw.MolDraw2DCairo(300, 300) # Replace with appropriate drawer for your environment
    d.drawOptions().prepareMolsBeforeDrawing=False
    Draw.PrepareAndDrawMolecule(d, molecule, highlightAtoms=hit_atoms, highlightBonds=hit_bonds)
    d.FinishDrawing()

    from IPython.display import Image
    png = d.GetDrawingText()
    pngs.append(png)
# Out:
# [1, 80, 650, 807, 1057, 1114, 1152, 1380, 1873]
# 1 ((1, 0), (4, 0))
# 80 ((5, 0),)
# 650 ((16, 0),)
# 807 ((2, 0), (15, 0))
# 1057 ((0, 0), (18, 0))
# 1114 ((8, 0),)
# 1152 ((3, 0), (17, 0))
# 1380 ((6, 0), (9, 0), (10, 0))
# 1873 ((7, 0), (11, 0), (12, 0), (13, 0), (14, 0))

# %%
display(*[Image(_) for _ in pngs])
